# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}
fields = {"_id":1, "AddressLine1":1, "AddressLine2":1, "AddressLine3":1, "BusinessName":1, "BusinessType":1, "BusinessTypeID":1, 
          "PostCode":1, "RatingDate":1, "RatingValue":1, "geocode":1, "scores":1}

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))
# Display the first document in the results using pprint
print()
pprint(establishments.find(query, fields)[0])
# Out:
# 41
#
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingValue': 0,
#  '_id': ObjectId('67bcbd4d1fa5736fc5d97495'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
result = establishments.find(query, fields).sort(sort)
df_hygiene = pd.json_normalize(result)

# Display the number of rows in the DataFrame
pprint(df_hygiene.shape)
# Display the first 10 rows of the DataFrame
df_hygiene.head(10)
# Out:
# (41, 15)
#                         _id               BusinessName  \
# 0  67bcbd4d1fa5736fc5d97495        The Chase Rest Home
# 1  67bcbd4d1fa5736fc5d97816                 Brenalwood
# 2  67bcbd4e1fa5736fc5d97b20              Melrose Hotel
# 3  67bcbd4e1fa5736fc5d97d0e              Seaford Pizza
# 4  67bcbd4e1fa5736fc5d97d1d              Golden Palace
# 5  67bcbd4f1fa5736fc5d986bc           Ashby's Butchers
# 6  67bcbd4f1fa5736fc5d988dd  South Sea Express Cuisine
# 7  67bcbd521fa5736fc5d99e08              Golden Palace
# 8  67bcbd521fa5736fc5d9a24c             The Tulip Tree
# 9  67bcbd531fa5736fc5d9aa5e                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  PostCode  RatingValue  \
# 0          Eastbourne  East Sussex  BN21 1BU            0
# 1  Walton-on-the-Naze        Essex  CO14 8HN            0
# 2      Clacton On Sea        Essex  CO15 6AD            0
# 3             Seaford  East Sussex  BN25 1PG            1
# 4             Seaford  East Sussex  BN25 1HP            1
# 5     Southend-On-Sea        Essex   SS1 2PP            0
# 6     Southend-on-sea        Essex   SS1 1BW            0
# 7            Rayleigh        Essex   SS6 9HN            0
# 8       Chiddingstone         KENT   TN8 7AH            1
# 9      81 Southernhay     Basildon  SS14 1EU            0
#
#             RatingDate  scores.Hygiene  scores.Structural  \
# 0  2021-09-23T00:00:00              20                 20
# 1  2022-06-22T00:00:00              20                 15
# 2  2021-08-13T00:00:00              20                 20
# 3  2021-12-23T00:00:00              20                 10
# 4  2021-10-07T00:00:00              20                 10
# 5  2022-07-21T00:00:00              20                 20
# 6  2022-08-03T00:00:00              20                 20
# 7  2022-03-23T00:00:00              20                 15
# 8  2022-03-04T00:00:00              20                  5
# 9  2021-07-26T00:00:00              20                 20
#
#    scores.ConfidenceInManagement  geocode.longitude  geocode.latitude
# 0                             20           0.276940         50.769705
# 1                             30           1.278721         51.857536
# 2                             20           1.159270         51.789429
# 3                             20           0.102020         50.770885
# 4                             20           0.101446         50.770724
# 5                             20           0.736349         51.541448
# 6                             20           0.712167         51.535007
# 7                             30           0.602364         51.591515
# 8                             20           0.146450         51.185947
# 9                             20           0.462307         51.570050

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"LocalAuthorityName": {"$regex": "London"},
        "RatingValue": {"$gte": 4}}
fields = {"_id":1, "AddressLine1":1, "AddressLine2":1, "AddressLine3":1, "BusinessName":1, "BusinessType":1, "BusinessTypeID":1, 
          "PostCode":1, "RatingDate":1, "RatingValue":1, "geocode":1, "scores":1}

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))
# Display the first document in the results using pprint
print()
pprint(establishments.find(query, fields)[0])
# Out:
# 33
#
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingValue': 4,
#  '_id': ObjectId('67bcbd501fa5736fc5d98eb0'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
result = establishments.find(query, fields).sort(sort)
df_london = pd.json_normalize(result)
# Display the number of rows in the DataFrame
print(df_london.shape)
# Display the first 10 rows of the DataFrame
df_london.head(10)
# Out:
# (33, 15)
#                         _id                          BusinessName  \
# 0  67bcbd571fa5736fc5d9d701                      Brick Lane Brews
# 1  67bcbd501fa5736fc5d98eb0                             Charlie's
# 2  67bcbd571fa5736fc5d9d8fc                            Caffè Nero
# 3  67bcbd581fa5736fc5d9db9c                Mv Sunborn Yacht Hotel
# 4  67bcbd581fa5736fc5d9dda7                     Good Hotel London
# 5  67bcbd501fa5736fc5d991d6               Mv City Cruises Erasmus
# 6  67bcbd521fa5736fc5d99d23             Benfleet Motor Yacht Club
# 7  67bcbd531fa5736fc5d9ab23  Coombs Catering t/a The Lock and Key
# 8  67bcbd531fa5736fc5d9ab24              Tilbury Seafarers Centre
# 9  67bcbd531fa5736fc5d9b22c                            Mv Valulla
#
#                         BusinessType  BusinessTypeID  \
# 0            Restaurant/Cafe/Canteen               1
# 1            Other catering premises            7841
# 2            Restaurant/Cafe/Canteen               1
# 3  Hotel/bed & breakfast/guest house            7842
# 4            Other catering premises            7841
# 5            Other catering premises            7841
# 6            Other catering premises            7841
# 7            Restaurant/Cafe/Canteen               1
# 8            Restaurant/Cafe/Canteen               1
# 9            Other catering premises            7841
#
#                                         AddressLine1  \
# 0                       Air side London City Airport
# 1         Oak Apple Farm Building 103 Sheernes Docks
# 2       London City Airport Airside Departure Lounge
# 3                                    Western Gateway
# 4                Western Gateway Royal Victoria Dock
# 5                                 Cherry Garden Pier
# 6                                         Ferry Road
# 7                                  Leslie Ford House
# 8                          Tenants Row Tilbury Docks
# 9  Reeds River Cruises LtdKings ReachRiver Thames...
#
#                                    AddressLine2 AddressLine3  PostCode  \
# 0                                        London                E16 2PX
# 1                                   Sheppy Kent                   ME12
# 2                            Royal Docks London                E16 2PJ
# 3                           Royal Victoria Dock                E16 1XL
# 4  Floating Platform next to Emirates Cable Car                E16 1FA
# 5              Cherry Garden Street Rotherhithe     Charlton   TN4 8HR
# 6                          South Benfleet Essex                SS7 1NF
# 7                                       Tilbury     Charlton  RM18 7EH
# 8                                 Tilbury Essex               RM18 7EH
# 9                                        London               RM15 5QY
#
#    RatingValue           RatingDate  scores.Hygiene  scores.Structural  \
# 0            4  2019-01-18T00:00:00              10                  5
# 1            4  2021-10-18T00:00:00               5                 10
# 2            5  2021-11-12T00:00:00               5                  5
# 3            5  2021-11-19T00:00:00               5                  5
# 4            5  2021-07-16T00:00:00               5                  5
# 5            5  2021-05-14T00:00:00               0                  5
# 6            4  2018-11-02T00:00:00               0                  0
# 7            5  2020-12-04T00:00:00               0                  5
# 8            5  2018-11-02T00:00:00               0                  0
# 9            5  2016-08-23T00:00:00               0                  0
#
#    scores.ConfidenceInManagement  geocode.longitude  geocode.latitude
# 0                              5           0.048006         51.503733
# 1                              5           0.508551         51.369321
# 2                              0           0.040518         51.504808
# 3                              5           0.027107         51.508170
# 4                              5           0.017920         51.507681
# 5                              0           0.249256         51.123623
# 6                             10           0.561954         51.543831
# 7                              0           0.346337         51.464066
# 8                              0           0.346325         51.464078
# 9                              0           0.287555         51.504071

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
# Latitude and Longitude of Penang Flavours
latitude = 51.49014200
longitude = 0.08384000

# Find by degree search, ensure going both negative and positive + rating equals 5
query = {"geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
        "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search},
        "RatingValue": 5}
fields = {"_id":1, "AddressLine1":1, "AddressLine2":1, "AddressLine3":1, "BusinessName":1, "BusinessType":1, "BusinessTypeID":1, 
          "PostCode":1, "RatingDate":1, "RatingValue":1, "geocode":1, "scores":1}

# Sorty by hygiene
sort = [("scores.Hygiene", 1)]
limit = 20

# Print the results
print(establishments.count_documents(query))

# Display the first document in the results using pprint
print()
pprint(establishments.find(query, fields).sort(sort).limit(limit)[0])
# Out:
# 87
#
# {'AddressLine1': '144 - 146 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'BusinessName': 'Iceland',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-11-13T00:00:00',
#  'RatingValue': 5,
#  '_id': ObjectId('67bcbd561fa5736fc5d9ccc7'),
#  'geocode': {'latitude': 51.4871482849121, 'longitude': 0.0924199968576431},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# Convert result to Pandas DataFrame
results = establishments.find(query, fields).sort(sort).limit(limit)
df_rating = pd.json_normalize(results)
# Display the number of rows in the DataFrame
print(df_rating.shape)
# Display the first 10 rows of the DataFrame
df_rating.head(15)
# Out:
# (20, 15)
#                          _id                         BusinessName  \
# 0   67bcbd561fa5736fc5d9cdc5                         The Old Mill
# 1   67bcbd561fa5736fc5d9cd59                           Abbi Wines
# 2   67bcbd561fa5736fc5d9cd0c              Plumstead Manor Nursery
# 3   67bcbd561fa5736fc5d9cdb5              High Street News & Wine
# 4   67bcbd561fa5736fc5d9cd0f                    Atlantic Fish Bar
# 5   67bcbd561fa5736fc5d9ccf4                            Volunteer
# 6   67bcbd561fa5736fc5d9cddc                           The Belfry
# 7   67bcbd561fa5736fc5d9ce09              Best Halal Meat Limited
# 8   67bcbd561fa5736fc5d9ccd7  Howe and Co Fish and Chips - Van 17
# 9   67bcbd561fa5736fc5d9cd57                Dosa & Sambal Express
# 10  67bcbd561fa5736fc5d9cd2f                               Greggs
# 11  67bcbd561fa5736fc5d9cd95                     Dilkush Tandoori
# 12  67bcbd561fa5736fc5d9ccc7                              Iceland
# 13  67bcbd561fa5736fc5d9cd30                                Tesco
# 14  67bcbd561fa5736fc5d9cdf8                Conway Primary School
#
#                              BusinessType  BusinessTypeID  \
# 0                       Pub/bar/nightclub            7843
# 1                       Retailers - other            4613
# 2                         Caring Premises               5
# 3                       Retailers - other            4613
# 4                  Takeaway/sandwich shop            7844
# 5                       Pub/bar/nightclub            7843
# 6                       Pub/bar/nightclub            7843
# 7                       Retailers - other            4613
# 8                          Mobile caterer            7846
# 9                 Restaurant/Cafe/Canteen               1
# 10                 Takeaway/sandwich shop            7844
# 11                 Takeaway/sandwich shop            7844
# 12  Retailers - supermarkets/hypermarkets            7840
# 13  Retailers - supermarkets/hypermarkets            7840
# 14              School/college/university            7845
#
#                                          AddressLine1 AddressLine2  \
# 0                        The Old Mill 1 Old Mill Road
# 1                               12 - 14 Lakedale Road
# 2                Plumstead Manor School Old Mill Road
# 3                           104 Plumstead High Street
# 4                                    35 Lakedale Road
# 5                     130 - 132 Plumstead High Street
# 6                           100 Plumstead High Street
# 7                            94 Plumstead High Street
# 8   Restaurant And Premises 107A Plumstead High St...
# 9                          107A Plumstead High Street
# 10                                    6 Lakedale Road
# 11                           99 Plumstead High Street
# 12                    144 - 146 Plumstead High Street
# 13                                   18 Lakedale Road
# 14               Conway Primary School Gallosson Road
#
#    AddressLine3  PostCode  RatingValue           RatingDate  scores.Hygiene  \
# 0     Plumstead  SE18 1QG            5  2022-03-16T00:00:00               0
# 1     Plumstead  SE18 1PP            5  2021-08-23T00:00:00               0
# 2     Plumstead  SE18 1QG            5  2021-06-16T00:00:00               0
# 3     Plumstead  SE18 1SJ            5  2021-01-19T00:00:00               0
# 4     Plumstead  SE18 1PR            5  2021-06-16T00:00:00               0
# 5     Plumstead  SE18 1JQ            5  2019-08-05T00:00:00               0
# 6     Plumstead  SE18 1SJ            5  2021-08-28T00:00:00               0
# 7     Plumstead  SE18 1SL            5  2021-11-17T00:00:00               0
# 8     Plumstead  SE18 1SE            5  2021-11-11T00:00:00               0
# 9     Plumstead                      5  2020-07-09T00:00:00               0
# 10    Plumstead  SE18 1PP            5  2021-06-23T00:00:00               0
# 11    Plumstead  SE18 1SB            5  2021-06-10T00:00:00               0
# 12    Plumstead  SE18 1JQ            5  2019-11-13T00:00:00               0
# 13    Plumstead  SE18 1PP            5  2020-10-20T00:00:00               0
# 14    Plumstead  SE18 1QY            5  2022-06-09T00:00:00               0
#
#     scores.Structural  scores.ConfidenceInManagement  geocode.longitude  \
# 0                   5                              5           0.084096
# 1                   0                              0           0.090889
# 2                   0                              5           0.085994
# 3                   5                              0           0.090323
# 4                   0                              5           0.091216
# 5                   0                              0           0.092080
# 6                   0                              0           0.090076
# 7                   0                              5           0.089611
# 8                   0                              0           0.092537
# 9                   0                              5           0.091566
# 10                  0                              0           0.091282
# 11                  5                              0           0.090967
# 12                  5                              5           0.092420
# 13                  5                              0           0.091282
# 14                  5                              0           0.089486
#
#     geocode.latitude
# 0          51.481711
# 1          51.487140
# 2          51.481518
# 3          51.487672
# 4          51.486730
# 5          51.487344
# 6          51.487928
# 7          51.488161
# 8          51.487534
# 9          51.487758
# 10         51.487141
# 11         51.487894
# 12         51.487148
# 13         51.487141
# 14         51.487865

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene': 0}}

# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id': "$LocalAuthorityName", 'num_restaurants': { '$sum': 1 }}}

# 3. Sorts the matches from highest to lowest
sort_values = {'$sort': { 'num_restaurants': -1}}

# Pipeline
pipeline = [match_query, group_query, sort_values]
# Print the number of documents in the result
results = list(establishments.aggregate(pipeline))
# Print the first 10 results
pprint(results[:10])
# Out:
# [{'_id': 'Thanet', 'num_restaurants': 1130},
#  {'_id': 'Greenwich', 'num_restaurants': 882},
#  {'_id': 'Maidstone', 'num_restaurants': 713},
#  {'_id': 'Newham', 'num_restaurants': 711},
#  {'_id': 'Swale', 'num_restaurants': 686},
#  {'_id': 'Chelmsford', 'num_restaurants': 680},
#  {'_id': 'Medway', 'num_restaurants': 672},
#  {'_id': 'Bexley', 'num_restaurants': 607},
#  {'_id': 'Southend-On-Sea', 'num_restaurants': 586},
#  {'_id': 'Tendring', 'num_restaurants': 542}]

# %%
# Convert the result to a Pandas DataFrame
df_count = pd.json_normalize(results)
# Display the number of rows in the DataFrame
print(df_count.shape)
# Display the first 10 rows of the DataFrame
df_count.head(10)
# Out:
# (55, 2)
#                _id  num_restaurants
# 0           Thanet             1130
# 1        Greenwich              882
# 2        Maidstone              713
# 3           Newham              711
# 4            Swale              686
# 5       Chelmsford              680
# 6           Medway              672
# 7           Bexley              607
# 8  Southend-On-Sea              586
# 9         Tendring              542
